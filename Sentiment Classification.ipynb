# %%
# !pip install torch
# Out:
# Collecting torch
#   Downloading torch-1.8.1-cp38-cp38-win_amd64.whl (190.5 MB)
# Requirement already satisfied: typing-extensions in c:\users\zach\appdata\roaming\python\python38\site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in c:\users\zach\appdata\roaming\python\python38\site-packages (from torch) (1.19.5)
# Installing collected packages: torch
# Successfully installed torch-1.8.1
#   WARNING: The scripts convert-caffe2-to-onnx.exe and convert-onnx-to-caffe2.exe are installed in 'C:\Users\Zach\anaconda3\envs\titanic\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import pandas as pd
import torch
import numpy
import torch.nn as nn

# %%
twitter_df = pd.read_csv('Data/twitter_data_clean.csv')
twitter_df['tweet'].head()
# Out:
# C:\Users\Zach\anaconda3\envs\titanic\lib\site-packages\IPython\core\interactiveshell.py:3145: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# 0    episode 13 crypto thunderdome part 1 prize 50 ...
# 1    grt chart going off the screen lambo soon btc ...
# 2    live bitcoin trading with deribot on deribit e...
# 3    deribot daily trading report 20122020 1107 utc...
# 4    learned about stellar amp earned xlm in return...
# Name: tweet, dtype: object

# %%
training_df = pd.read_csv('Data/training_data_clean.csv')
training_df = training_df.sample(n=100000, random_state=100)
training_df.head()
# Out:
#          sentiment                                              tweet
# 975371           4      i did not realise you had a monome cool stuff
# 1276867          4  watching tv texting sitting with my bro and bf...
# 103630           0  why would i dload an app called the quotmoron ...
# 482837           0                              i feel so bad for him
# 219956           0  can not sleepagaintoo much rattling around in ...

# %%
training_df = training_df.dropna()

# %%
list_of_tweets = training_df['tweet'].tolist()
from collections import Counter

all_text = ' '.join(list_of_tweets)
words = all_text.split()

count_words = Counter(words)
total_words = len(words)
sorted_words = count_words.most_common(total_words)
vocab_to_int = {w:i+1 for i, (w,c) in enumerate(sorted_words)}

# %%
import numpy as np

# Return features of tweet ints, where each tweet is padded with 0's or truncated to the input seq_length.
def pad_features(tweet_int, seq_length):
        
    tweet_len = len(tweet_int)
        
    if tweet_len <= seq_length:
        zeroes = list(np.zeros(seq_length-tweet_len))
        new = zeroes+tweet_int
    elif tweet_len > seq_length:
        new = tweet_int[0:seq_length]
            
    return np.asarray(new)

# %%
from string import punctuation

def tokenize_review(test_review):
    test_review = test_review.lower() # lowercase
    # get rid of punctuation
    test_text = ''.join([c for c in test_review if c not in punctuation])

    # splitting by spaces
    test_words = test_text.split()

    # tokens
    test_ints = []
    for word in test_words:
        if word in vocab_to_int:
            test_ints.append(vocab_to_int[word])
    #test_ints.append([vocab_to_int[word] for word in test_words])
    
    return test_ints

# %%
class SentimentLSTM(nn.Module):
    """
    The RNN model that will be used to perform Sentiment analysis.
    """

    def __init__(self, vocab_size, output_size, embedding_dim, hidden_dim, n_layers, drop_prob=0.5):
        """
        Initialize the model by setting up the layers.
        """
        super().__init__()

        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim
        
        # embedding and LSTM layers
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, n_layers, 
                            dropout=drop_prob)
        
        # dropout layer
        self.dropout = nn.Dropout(0.3)
        
        # linear and sigmoid layers
        self.fc = nn.Linear(hidden_dim, output_size)
        self.sig = nn.Sigmoid()
        

    def forward(self, x, hidden):
        """
        Perform a forward pass of our model on some input and hidden state.
        """
        batch_size = x.size(0)
        
        # embeddings and lstm_out
        embeds = self.embedding(x)
        lstm_out, hidden = self.lstm(embeds, hidden)
    
        # stack up lstm outputs
        lstm_out = lstm_out.contiguous().view(-1, self.hidden_dim)
        
        # dropout and fully-connected layer
        out = self.dropout(lstm_out)
        out = self.fc(out)
        # sigmoid function
        sig_out = self.sig(out)
        
        # reshape to be batch_size first
        sig_out = sig_out.view(batch_size, -1)
        sig_out = sig_out[:, -1] # get last batch of labels
        
        # return last sigmoid output and hidden state
        return sig_out, hidden
    
    
    def init_hidden(self, batch_size):
        ''' Initializes hidden state '''
        # Create two new tensors with sizes n_layers x batch_size x hidden_dim,
        # initialized to zero, for hidden state and cell state of LSTM
        weight = next(self.parameters()).data
        
        if (False):
            hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().cuda(),
                  weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().cuda())
        else:
            hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_(),
                      weight.new(self.n_layers, batch_size, self.hidden_dim).zero_())
        
        return hidden

# %%
vocab_size = 67394
output_size = 1
embedding_dim = 400
hidden_dim = 256

n_layers = 2
model = SentimentLSTM(vocab_size, output_size, embedding_dim, hidden_dim, n_layers)

model.load_state_dict(torch.load('sentiment_analysis.pt'))
# Out:
# <All keys matched successfully>

# %%
def predict(net, test_review, sequence_length=20):
    
    net.eval()
    
    # tokenize review
    test_ints = tokenize_review(test_review)
    
    # pad tokenized sequence
    seq_length=sequence_length
    features = pad_features(test_ints, seq_length)
    
    # convert to tensor to pass into your model
    feature_tensor = torch.from_numpy(features)
    
    batch_size = feature_tensor.size(0)
    
    # initialize hidden state
    h = net.init_hidden(batch_size)
    
    if(False):
        feature_tensor = feature_tensor.cuda()

    feature_tensor = feature_tensor.unsqueeze(0)

    
    # get the output from the model
    output, h = net(feature_tensor.to(torch.int64), h)
    
    # convert output probabilities to predicted class (0 or 1)
    pred = torch.round(output.squeeze()) 
    # printing output value, before rounding
    print('Prediction value, pre-rounding: {:.6f}'.format(output.item()))
    
    # print custom response
    if(pred.item()==1):
        return 1
    else:
        return 0

# %%
print(predict(model, "im so upset"))
# Out:
# Prediction value, pre-rounding: 0.215993
# 0

# %%
twitter_df['sentiment'] = twitter_df.apply(lambda row: predict(model, row['tweet']), axis=1)
# Out:
# on value, pre-rounding: 0.579213
# Prediction value, pre-rounding: 0.594472
# Prediction value, pre-rounding: 0.142449
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.257072
# Prediction value, pre-rounding: 0.774881
# Prediction value, pre-rounding: 0.116276
# Prediction value, pre-rounding: 0.907602
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.007730
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.923714
# Prediction value, pre-rounding: 0.219093
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.007730
# Prediction value, pre-rounding: 0.907602
# Prediction value, pre-rounding: 0.174183
# Prediction value, pre-rounding: 0.826274
# Prediction value, pre-rounding: 0.024387
# Prediction value, pre-rounding: 0.377085
# Prediction value, pre-rounding: 0.977723
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.977723
# Prediction value, pre-rounding: 0.965517
# Prediction value, pre-rounding: 0.830434
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.967111
# Prediction value, pre-rounding: 0.442710
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.977636
# Prediction value, pre-rounding: 0.307940
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.973946
# Prediction value, pre-rounding: 0.994367
# Prediction value, pre-rounding: 0.902777
# Prediction value, pre-rounding: 0.157471
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.614428
# Prediction value, pre-rounding: 0.313310
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.761128
# Prediction value, pre-rounding: 0.798331
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.435733
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.979607
# Prediction value, pre-rounding: 0.994401
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.710742
# Prediction value, pre-rounding: 0.149191
# Prediction value, pre-rounding: 0.955615
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.968445
# Prediction value, pre-rounding: 0.863367
# Prediction value, pre-rounding: 0.977255
# Prediction value, pre-rounding: 0.786005
# Prediction value, pre-rounding: 0.065071
# Prediction value, pre-rounding: 0.649823
# Prediction value, pre-rounding: 0.710742
# Prediction value, pre-rounding: 0.741957
# Prediction value, pre-rounding: 0.975503
# Prediction value, pre-rounding: 0.133383
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.614608
# Prediction value, pre-rounding: 0.989933
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.157471
# Prediction value, pre-rounding: 0.832066
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.758004
# Prediction value, pre-rounding: 0.575119
# Prediction value, pre-rounding: 0.722485
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.947547
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.758004
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.994959
# Prediction value, pre-rounding: 0.817293
# Prediction value, pre-rounding: 0.954912
# Prediction value, pre-rounding: 0.954912
# Prediction value, pre-rounding: 0.028427
# Prediction value, pre-rounding: 0.343979
# Prediction value, pre-rounding: 0.207352
# Prediction value, pre-rounding: 0.282353
# Prediction value, pre-rounding: 0.324748
# Prediction value, pre-rounding: 0.142449
# Prediction value, pre-rounding: 0.720900
# Prediction value, pre-rounding: 0.153226
# Prediction value, pre-rounding: 0.153572
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.528213
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.946390
# Prediction value, pre-rounding: 0.649823
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.035853
# Prediction value, pre-rounding: 0.227004
# Prediction value, pre-rounding: 0.378785
# Prediction value, pre-rounding: 0.056269
# Prediction value, pre-rounding: 0.902777
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.923714
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.947547
# Prediction value, pre-rounding: 0.493306
# Prediction value, pre-rounding: 0.437400
# Prediction value, pre-rounding: 0.832237
# Prediction value, pre-rounding: 0.583489
# Prediction value, pre-rounding: 0.959764
# Prediction value, pre-rounding: 0.896472
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.036902
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.028427
# Prediction value, pre-rounding: 0.977723
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.414941
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.544116
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.863367
# Prediction value, pre-rounding: 0.799963
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.777712
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.157471
# Prediction value, pre-rounding: 0.052316
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.795247
# Prediction value, pre-rounding: 0.726971
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.649823
# Prediction value, pre-rounding: 0.724249
# Prediction value, pre-rounding: 0.239927
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.868824
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.748885
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.680165
# Prediction value, pre-rounding: 0.091787
# Prediction value, pre-rounding: 0.257072
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.960583
# Prediction value, pre-rounding: 0.561505
# Prediction value, pre-rounding: 0.236769
# Prediction value, pre-rounding: 0.214871
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.830434
# Prediction value, pre-rounding: 0.613223
# Prediction value, pre-rounding: 0.832237
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.741957
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.905253
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.964193
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.230970
# Prediction value, pre-rounding: 0.574780
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.192961
# Prediction value, pre-rounding: 0.500948
# Prediction value, pre-rounding: 0.036602
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.068628
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.632677
# Prediction value, pre-rounding: 0.010224
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.387250
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.788800
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.780404
# Prediction value, pre-rounding: 0.286925
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.149191
# Prediction value, pre-rounding: 0.798331
# Prediction value, pre-rounding: 0.322179
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.653837
# Prediction value, pre-rounding: 0.989933
# Prediction value, pre-rounding: 0.947547
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.945675
# Prediction value, pre-rounding: 0.597095
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.762407
# Prediction value, pre-rounding: 0.967520
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.964766
# Prediction value, pre-rounding: 0.901568
# Prediction value, pre-rounding: 0.068628
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.749914
# Prediction value, pre-rounding: 0.989933
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.436790
# Prediction value, pre-rounding: 0.819992
# Prediction value, pre-rounding: 0.715304
# Prediction value, pre-rounding: 0.272501
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.758004
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.007244
# Prediction value, pre-rounding: 0.978578
# Prediction value, pre-rounding: 0.413803
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.902777
# Prediction value, pre-rounding: 0.402269
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.832237
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.993612
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.007730
# Prediction value, pre-rounding: 0.511603
# Prediction value, pre-rounding: 0.922408
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.902777
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.363376
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.923714
# Prediction value, pre-rounding: 0.971864
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.754959
# Prediction value, pre-rounding: 0.140941
# Prediction value, pre-rounding: 0.013030
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.570358
# Prediction value, pre-rounding: 0.295149
# Prediction value, pre-rounding: 0.879473
# Prediction value, pre-rounding: 0.865994
# Prediction value, pre-rounding: 0.307007
# Prediction value, pre-rounding: 0.885254
# Prediction value, pre-rounding: 0.196699
# Prediction value, pre-rounding: 0.597163
# Prediction value, pre-rounding: 0.544040
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.715304
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.570358
# Prediction value, pre-rounding: 0.835416
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.227004
# Prediction value, pre-rounding: 0.798331
# Prediction value, pre-rounding: 0.194090
# Prediction value, pre-rounding: 0.748885
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.760418
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.960583
# Prediction value, pre-rounding: 0.583489
# Prediction value, pre-rounding: 0.977723
# Prediction value, pre-rounding: 0.327066
# Prediction value, pre-rounding: 0.391952
# Prediction value, pre-rounding: 0.075238
# Prediction value, pre-rounding: 0.649823
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.583489
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.710548
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.710548
# Prediction value, pre-rounding: 0.754959
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.808222
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.302522
# Prediction value, pre-rounding: 0.528213
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.591182
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.895715
# Prediction value, pre-rounding: 0.895715
# Prediction value, pre-rounding: 0.460092
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.246754
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.007730
# Prediction value, pre-rounding: 0.006921
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.774478
# Prediction value, pre-rounding: 0.343979
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.960583
# Prediction value, pre-rounding: 0.800008
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.612226
# Prediction value, pre-rounding: 0.378785
# Prediction value, pre-rounding: 0.835416
# Prediction value, pre-rounding: 0.933475
# Prediction value, pre-rounding: 0.992137
# Prediction value, pre-rounding: 0.343979
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.521044
# Prediction value, pre-rounding: 0.621975
# Prediction value, pre-rounding: 0.973760
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.863367
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.713770
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.210530
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.378785
# Prediction value, pre-rounding: 0.773832
# Prediction value, pre-rounding: 0.748885
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.120441
# Prediction value, pre-rounding: 0.700895
# Prediction value, pre-rounding: 0.967520
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.863367
# Prediction value, pre-rounding: 0.764135
# Prediction value, pre-rounding: 0.290042
# Prediction value, pre-rounding: 0.973946
# Prediction value, pre-rounding: 0.540302
# Prediction value, pre-rounding: 0.463492
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.760085
# Prediction value, pre-rounding: 0.570795
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.992411
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.741957
# Prediction value, pre-rounding: 0.365990
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.603655
# Prediction value, pre-rounding: 0.739831
# Prediction value, pre-rounding: 0.989933
# Prediction value, pre-rounding: 0.021675
# Prediction value, pre-rounding: 0.343979
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.691332
# Prediction value, pre-rounding: 0.947547
# Prediction value, pre-rounding: 0.919270
# Prediction value, pre-rounding: 0.149191
# Prediction value, pre-rounding: 0.959469
# Prediction value, pre-rounding: 0.936788
# Prediction value, pre-rounding: 0.918801
# Prediction value, pre-rounding: 0.734047
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.207352
# Prediction value, pre-rounding: 0.875632
# Prediction value, pre-rounding: 0.135837
# Prediction value, pre-rounding: 0.370674
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.891773
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.797495
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.089967
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.023790
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.053652
# Prediction value, pre-rounding: 0.780404
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.990099
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.157471
# Prediction value, pre-rounding: 0.569613
# Prediction value, pre-rounding: 0.043645
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.479110
# Prediction value, pre-rounding: 0.710548
# Prediction value, pre-rounding: 0.551324
# Prediction value, pre-rounding: 0.959469
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.149037
# Prediction value, pre-rounding: 0.832237
# Prediction value, pre-rounding: 0.559629
# Prediction value, pre-rounding: 0.696551
# Prediction value, pre-rounding: 0.149037
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.337790
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.583489
# Prediction value, pre-rounding: 0.583489
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.370674
# Prediction value, pre-rounding: 0.068628
# Prediction value, pre-rounding: 0.111009
# Prediction value, pre-rounding: 0.157471
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.014172
# Prediction value, pre-rounding: 0.755192
# Prediction value, pre-rounding: 0.563108
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.979682
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.026168
# Prediction value, pre-rounding: 0.748885
# Prediction value, pre-rounding: 0.292573
# Prediction value, pre-rounding: 0.021675
# Prediction value, pre-rounding: 0.006394
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.746569
# Prediction value, pre-rounding: 0.710742
# Prediction value, pre-rounding: 0.832237
# Prediction value, pre-rounding: 0.651562

# %%
twitter_df.head()
# Out:
#    Unnamed: 0                   id      conversation_id           created_at  \
# 0       64835  1340558190652506112  1340558190652506112  2020-12-20 02:22:33
# 1       24163  1340590202562080768  1340542774454587392  2020-12-20 04:29:45
# 2       24035  1340616069153771521  1340616069153771521  2020-12-20 06:12:32
# 3       12100  1340617072448069632  1340617072448069632  2020-12-20 06:16:32
# 4       64728  1340637885326741504  1340637885326741504  2020-12-20 07:39:14
#
#          date      time  timezone              user_id      username  \
# 0  2020-12-20  02:22:33      -500             15061990      tjeezyyy
# 1  2020-12-20  04:29:45      -500  1277617350745796610   bittradebtc
# 2  2020-12-20  06:12:32      -500           1624918207   deribotinfo
# 3  2020-12-20  06:16:32      -500           1624918207   deribotinfo
# 4  2020-12-20  07:39:14      -500           2231159425  thepixiepost
#
#                                        name  ... source user_rt_id user_rt  \
# 0  jeezy, a love story 🤰 tokennotneeded.com  ...    NaN        NaN     NaN
# 1                                  Bittrade  ...    NaN        NaN     NaN
# 2                              DeriBot.info  ...    NaN        NaN     NaN
# 3                              DeriBot.info  ...    NaN        NaN     NaN
# 4              Jenn Nieto 🐝I ♥️ CTP & HIVE🐝  ...    NaN        NaN     NaN
#
#   retweet_id reply_to retweet_date  translate  trans_src  trans_dest sentiment
# 0        NaN       []          NaN        NaN        NaN         NaN         1
# 1        NaN       []          NaN        NaN        NaN         NaN         1
# 2        NaN       []          NaN        NaN        NaN         NaN         0
# 3        NaN       []          NaN        NaN        NaN         NaN         1
# 4        NaN       []          NaN        NaN        NaN         NaN         0
#
# [5 rows x 38 columns]

# %%
twitter_df.to_csv('twitter_labeled.csv')

# %%
reddit_df = pd.read_csv('Data/reddit_data.csv')
reddit_df['body'].head()
# Out:
# 0                       We can only hope my friend
# 1        We’re taking this rocket to the moon baby
# 2                                    all in bb 🚀🚀🚀
# 3    I love monero. Even more than I love stellar.
# 4              10 dollar a coin would be very nice
# Name: body, dtype: object

# %%
reddit_df['sentiment'] = reddit_df.apply(lambda row: predict(model, row['body']), axis=1)
# Out:
# on value, pre-rounding: 0.850697
# Prediction value, pre-rounding: 0.903862
# Prediction value, pre-rounding: 0.951696
# Prediction value, pre-rounding: 0.063387
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.393082
# Prediction value, pre-rounding: 0.068412
# Prediction value, pre-rounding: 0.850283
# Prediction value, pre-rounding: 0.923404
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.140941
# Prediction value, pre-rounding: 0.632677
# Prediction value, pre-rounding: 0.035853
# Prediction value, pre-rounding: 0.024387
# Prediction value, pre-rounding: 0.563108
# Prediction value, pre-rounding: 0.597095
# Prediction value, pre-rounding: 0.301484
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.928734
# Prediction value, pre-rounding: 0.781250
# Prediction value, pre-rounding: 0.891269
# Prediction value, pre-rounding: 0.169492
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.914237
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.793090
# Prediction value, pre-rounding: 0.973174
# Prediction value, pre-rounding: 0.993612
# Prediction value, pre-rounding: 0.647605
# Prediction value, pre-rounding: 0.039652
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.004028
# Prediction value, pre-rounding: 0.207352
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.774881
# Prediction value, pre-rounding: 0.796089
# Prediction value, pre-rounding: 0.713332
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.193050
# Prediction value, pre-rounding: 0.536850
# Prediction value, pre-rounding: 0.708779
# Prediction value, pre-rounding: 0.317467
# Prediction value, pre-rounding: 0.230970
# Prediction value, pre-rounding: 0.111009
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.052316
# Prediction value, pre-rounding: 0.987675
# Prediction value, pre-rounding: 0.116438
# Prediction value, pre-rounding: 0.049634
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.858247
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.187450
# Prediction value, pre-rounding: 0.074760
# Prediction value, pre-rounding: 0.286345
# Prediction value, pre-rounding: 0.075238
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.859632
# Prediction value, pre-rounding: 0.614054
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.307209
# Prediction value, pre-rounding: 0.718478
# Prediction value, pre-rounding: 0.814088
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.555492
# Prediction value, pre-rounding: 0.657154
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.540615
# Prediction value, pre-rounding: 0.711242
# Prediction value, pre-rounding: 0.111009
# Prediction value, pre-rounding: 0.935363
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.141812
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.624123
# Prediction value, pre-rounding: 0.981942
# Prediction value, pre-rounding: 0.991990
# Prediction value, pre-rounding: 0.898992
# Prediction value, pre-rounding: 0.172903
# Prediction value, pre-rounding: 0.530604
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.243342
# Prediction value, pre-rounding: 0.371312
# Prediction value, pre-rounding: 0.519128
# Prediction value, pre-rounding: 0.483943
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.817293
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.080764
# Prediction value, pre-rounding: 0.441216
# Prediction value, pre-rounding: 0.153226
# Prediction value, pre-rounding: 0.014503
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.903385
# Prediction value, pre-rounding: 0.014503
# Prediction value, pre-rounding: 0.903385
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.856372
# Prediction value, pre-rounding: 0.966494
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.563108
# Prediction value, pre-rounding: 0.068412
# Prediction value, pre-rounding: 0.403132
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.056385
# Prediction value, pre-rounding: 0.783064
# Prediction value, pre-rounding: 0.453574
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.410632
# Prediction value, pre-rounding: 0.933205
# Prediction value, pre-rounding: 0.212505
# Prediction value, pre-rounding: 0.441493
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.860198
# Prediction value, pre-rounding: 0.176762
# Prediction value, pre-rounding: 0.685553
# Prediction value, pre-rounding: 0.845087
# Prediction value, pre-rounding: 0.301484
# Prediction value, pre-rounding: 0.104052
# Prediction value, pre-rounding: 0.044644
# Prediction value, pre-rounding: 0.002446
# Prediction value, pre-rounding: 0.284059
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.964194
# Prediction value, pre-rounding: 0.427494
# Prediction value, pre-rounding: 0.774881
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.442710
# Prediction value, pre-rounding: 0.776121
# Prediction value, pre-rounding: 0.680208
# Prediction value, pre-rounding: 0.022918
# Prediction value, pre-rounding: 0.162594
# Prediction value, pre-rounding: 0.715304
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.197926
# Prediction value, pre-rounding: 0.092712
# Prediction value, pre-rounding: 0.301484
# Prediction value, pre-rounding: 0.918801
# Prediction value, pre-rounding: 0.570717
# Prediction value, pre-rounding: 0.168218
# Prediction value, pre-rounding: 0.770299
# Prediction value, pre-rounding: 0.673989
# Prediction value, pre-rounding: 0.542012
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.206217
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.124196
# Prediction value, pre-rounding: 0.737903
# Prediction value, pre-rounding: 0.331938
# Prediction value, pre-rounding: 0.746708
# Prediction value, pre-rounding: 0.774881
# Prediction value, pre-rounding: 0.661296
# Prediction value, pre-rounding: 0.774881
# Prediction value, pre-rounding: 0.058887
# Prediction value, pre-rounding: 0.902338
# Prediction value, pre-rounding: 0.075794
# Prediction value, pre-rounding: 0.212251
# Prediction value, pre-rounding: 0.662416
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.769391
# Prediction value, pre-rounding: 0.247155
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.976305
# Prediction value, pre-rounding: 0.018394
# Prediction value, pre-rounding: 0.776121
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.230970
# Prediction value, pre-rounding: 0.201465
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.038536
# Prediction value, pre-rounding: 0.760085
# Prediction value, pre-rounding: 0.375921
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.104052
# Prediction value, pre-rounding: 0.718478
# Prediction value, pre-rounding: 0.521044
# Prediction value, pre-rounding: 0.228903
# Prediction value, pre-rounding: 0.838797
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.874912
# Prediction value, pre-rounding: 0.333926
# Prediction value, pre-rounding: 0.560932
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.212251
# Prediction value, pre-rounding: 0.606975
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.065071
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.057693
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.046444
# Prediction value, pre-rounding: 0.122969
# Prediction value, pre-rounding: 0.842731
# Prediction value, pre-rounding: 0.748885
# Prediction value, pre-rounding: 0.210530
# Prediction value, pre-rounding: 0.482829
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.614374
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.377085
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.715304
# Prediction value, pre-rounding: 0.090131
# Prediction value, pre-rounding: 0.967312
# Prediction value, pre-rounding: 0.058887
# Prediction value, pre-rounding: 0.460092
# Prediction value, pre-rounding: 0.207352
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.776035
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.891773
# Prediction value, pre-rounding: 0.046829
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.079117
# Prediction value, pre-rounding: 0.662416
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.453681
# Prediction value, pre-rounding: 0.282353
# Prediction value, pre-rounding: 0.900987
# Prediction value, pre-rounding: 0.990601
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.931330
# Prediction value, pre-rounding: 0.609055
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.621975
# Prediction value, pre-rounding: 0.949905
# Prediction value, pre-rounding: 0.116438
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.045227
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.983827
# Prediction value, pre-rounding: 0.038536
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.075794
# Prediction value, pre-rounding: 0.176418
# Prediction value, pre-rounding: 0.881315
# Prediction value, pre-rounding: 0.442710
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.741460
# Prediction value, pre-rounding: 0.068412
# Prediction value, pre-rounding: 0.746708
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.212251
# Prediction value, pre-rounding: 0.452048
# Prediction value, pre-rounding: 0.079589
# Prediction value, pre-rounding: 0.521044
# Prediction value, pre-rounding: 0.634959
# Prediction value, pre-rounding: 0.960583
# Prediction value, pre-rounding: 0.403878
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.441493
# Prediction value, pre-rounding: 0.968127
# Prediction value, pre-rounding: 0.737903
# Prediction value, pre-rounding: 0.569484
# Prediction value, pre-rounding: 0.760085
# Prediction value, pre-rounding: 0.544040
# Prediction value, pre-rounding: 0.846978
# Prediction value, pre-rounding: 0.754096
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.340431
# Prediction value, pre-rounding: 0.189466
# Prediction value, pre-rounding: 0.770898
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.624123
# Prediction value, pre-rounding: 0.998853
# Prediction value, pre-rounding: 0.268754
# Prediction value, pre-rounding: 0.760085
# Prediction value, pre-rounding: 0.494244
# Prediction value, pre-rounding: 0.194910
# Prediction value, pre-rounding: 0.597163
# Prediction value, pre-rounding: 0.920172
# Prediction value, pre-rounding: 0.597095
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.972629
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.194090
# Prediction value, pre-rounding: 0.470175
# Prediction value, pre-rounding: 0.378785
# Prediction value, pre-rounding: 0.111009
# Prediction value, pre-rounding: 0.319214
# Prediction value, pre-rounding: 0.429938
# Prediction value, pre-rounding: 0.754959
# Prediction value, pre-rounding: 0.816463
# Prediction value, pre-rounding: 0.191496
# Prediction value, pre-rounding: 0.965287
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.965583
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.119089
# Prediction value, pre-rounding: 0.022072
# Prediction value, pre-rounding: 0.776121
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.900275
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.024387
# Prediction value, pre-rounding: 0.761483
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.845087
# Prediction value, pre-rounding: 0.962902
# Prediction value, pre-rounding: 0.526127
# Prediction value, pre-rounding: 0.009383
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.930805
# Prediction value, pre-rounding: 0.796376
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.077626
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.509540
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.453444
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.991614
# Prediction value, pre-rounding: 0.212251
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.949081
# Prediction value, pre-rounding: 0.761337
# Prediction value, pre-rounding: 0.819614
# Prediction value, pre-rounding: 0.988356
# Prediction value, pre-rounding: 0.261852
# Prediction value, pre-rounding: 0.576210
# Prediction value, pre-rounding: 0.994861
# Prediction value, pre-rounding: 0.858247
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.023790
# Prediction value, pre-rounding: 0.898992
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.441493
# Prediction value, pre-rounding: 0.442710
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.212251
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.329132
# Prediction value, pre-rounding: 0.276826
# Prediction value, pre-rounding: 0.403132
# Prediction value, pre-rounding: 0.842731
# Prediction value, pre-rounding: 0.441493
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.489291
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.691921
# Prediction value, pre-rounding: 0.590830
# Prediction value, pre-rounding: 0.805309
# Prediction value, pre-rounding: 0.738831
# Prediction value, pre-rounding: 0.996538
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.220902
# Prediction value, pre-rounding: 0.905113
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.756312
# Prediction value, pre-rounding: 0.220902
# Prediction value, pre-rounding: 0.651562
# Prediction value, pre-rounding: 0.470495
# Prediction value, pre-rounding: 0.811747
# Prediction value, pre-rounding: 0.202482
# Prediction value, pre-rounding: 0.854687
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.722485
# Prediction value, pre-rounding: 0.913790
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.978828
# Prediction value, pre-rounding: 0.338977
# Prediction value, pre-rounding: 0.988034
# Prediction value, pre-rounding: 0.891269
# Prediction value, pre-rounding: 0.514626
# Prediction value, pre-rounding: 0.338478
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.410632
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.519611
# Prediction value, pre-rounding: 0.317536
# Prediction value, pre-rounding: 0.990636
# Prediction value, pre-rounding: 0.597095
# Prediction value, pre-rounding: 0.211669
# Prediction value, pre-rounding: 0.704681
# Prediction value, pre-rounding: 0.973247
# Prediction value, pre-rounding: 0.955615
# Prediction value, pre-rounding: 0.183202
# Prediction value, pre-rounding: 0.327066
# Prediction value, pre-rounding: 0.563108
# Prediction value, pre-rounding: 0.063772
# Prediction value, pre-rounding: 0.623999
# Prediction value, pre-rounding: 0.257527
# Prediction value, pre-rounding: 0.435733
# Prediction value, pre-rounding: 0.764135
# Prediction value, pre-rounding: 0.245124
# Prediction value, pre-rounding: 0.138929
# Prediction value, pre-rounding: 0.470495
# Prediction value, pre-rounding: 0.313515
# Prediction value, pre-rounding: 0.202333
# Prediction value, pre-rounding: 0.519128
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.777127
# Prediction value, pre-rounding: 0.593362
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.676059
# Prediction value, pre-rounding: 0.683067
# Prediction value, pre-rounding: 0.948352
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.299363
# Prediction value, pre-rounding: 0.671367
# Prediction value, pre-rounding: 0.007109
# Prediction value, pre-rounding: 0.409610
# Prediction value, pre-rounding: 0.039069
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.306193
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.202333
# Prediction value, pre-rounding: 0.760085
# Prediction value, pre-rounding: 0.985335
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.879473
# Prediction value, pre-rounding: 0.063772
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.202333
# Prediction value, pre-rounding: 0.597095
# Prediction value, pre-rounding: 0.484624
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.349279
# Prediction value, pre-rounding: 0.965866
# Prediction value, pre-rounding: 0.408161
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.959385
# Prediction value, pre-rounding: 0.317467
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.484624
# Prediction value, pre-rounding: 0.988034
# Prediction value, pre-rounding: 0.858698
# Prediction value, pre-rounding: 0.484624
# Prediction value, pre-rounding: 0.576085
# Prediction value, pre-rounding: 0.287865
# Prediction value, pre-rounding: 0.414528
# Prediction value, pre-rounding: 0.091787
# Prediction value, pre-rounding: 0.601468
# Prediction value, pre-rounding: 0.567815
# Prediction value, pre-rounding: 0.736422
# Prediction value, pre-rounding: 0.816631
# Prediction value, pre-rounding: 0.140941
# Prediction value, pre-rounding: 0.725550
# Prediction value, pre-rounding: 0.266359

# %%
reddit_df.head()
# Out:
#    Unnamed: 0             author  \
# 0           0  ExcitingRelease95
# 1           1           GoobyBTC
# 2           2          beans_lel
# 3           3         9107201999
# 4           4          ljayyskux
#
#                                             body  created_utc     created  \
# 0                     We can only hope my friend   1611205194  1611223194
# 1      We’re taking this rocket to the moon baby   1611204949  1611222949
# 2                                  all in bb 🚀🚀🚀   1611204458  1611222458
# 3  I love monero. Even more than I love stellar.   1611204333  1611222333
# 4            10 dollar a coin would be very nice   1611202623  1611220623
#
#         created_at  sentiment
# 0  1/20/2021 23:59          0
# 1  1/20/2021 23:55          1
# 2  1/20/2021 23:47          0
# 3  1/20/2021 23:45          1
# 4  1/20/2021 23:17          1

# %%
reddit_df.to_csv('reddit_labeled.csv')
